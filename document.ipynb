# %%
from langchain_core.documents import Document

document = Document(
    page_content="This is the main content i am using for RAG",
    metadata={
        "source": "example.txt",
        "pages": 1,
        "author": "Faheem Jawaid",
        "date_created": "2026-01-01"
    }
)
document
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Faheem Jawaid', 'date_created': '2026-01-01'}, page_content='This is the main content i am using for RAG')

# %%
#Text Loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("./docs/tesla.txt", encoding="utf-8")

result = loader.load()
result
# Out:
# [Document(metadata={'source': './docs/tesla.txt'}, page_content='Tesla, Inc. (/ˈtɛzlə/ TEZ-lə or /ˈtɛslə/ ⓘ TESS-lə[a]) is an American multinational automotive and clean energy company. Headquartered in Austin, Texas, it designs, manufactures, and sells battery electric vehicles (BEVs), stationary battery energy storage devices from home to grid-scale, solar panels and solar shingles, and related products and services.\n\nThe company was incorporated in July 2003 by Martin Eberhard and Marc Tarpenning as Tesla Motors. Its name is a tribute to the inventor and electrical engineer Nikola Tesla. In February 2004, Elon Musk led Tesla\'s first funding round and became the company\'s chairman, subsequently claiming to be a co-founder; in 2008, he was named chief executive officer. The company began production of its first car model, the Roadster sports car, in 2008; the Model S sedan in 2012; the Model X SUV in 2015; the Model 3 sedan in 2017; the Model Y crossover in 2020; the Tesla Semi truck in 2022; and the Cybertruck pickup truck in 2023.\n\nTesla is one of the world\'s most valuable companies in terms of market capitalization. Starting in July 2020, it has been the world\'s most valuable automaker. From October 2021 to March 2022, Tesla was a US$1 trillion company, the sixth US company to reach that valuation. In 2023, the company was ranked 69th in the Forbes Global 2000.[5] In 2024, the company led the battery electric vehicle market, with 17.6% share.\n\nTesla exceeded $1 trillion in market capitalization again between November 2024[6] and February 2025,[7] and from May 2025 to July 2026.[8] In November 2025, Tesla approved a pay package worth $1 trillion for Musk, which he is to receive over 10 years if he meets specific goals.[9] By the end of 2025, the company lost its status as world\'s leading manufacturer of electric vehicles.[10]\n\nTesla has been the subject of lawsuits, boycotts, government scrutiny, and journalistic criticism, stemming from allegations of multiple cases of whistleblower retaliation, worker rights violations such as sexual harassment and anti-union activities, safety defects leading to dozens of recalls, the lack of a public relations department, and controversial statements from Musk, including overpromising on the company\'s driving assist technology and product release timelines.\n\nHistory\nMain article: History of Tesla, Inc.\nFounding (2003–2004)\nThe company was incorporated as Tesla Motors, Inc., on July 1, 2003, by Martin Eberhard and Marc Tarpenning.[11][12] They served as chief executive officer and chief financial officer, respectively.[13] Eberhard said that he wanted to build "a car manufacturer that is also a technology company", with its core technologies as "the battery, the computer software, and the proprietary motor".[14]\n\nIan Wright joined Eberhard and Tarpenning a few months later.[11] In February 2004, the company raised US$7.5 million (equivalent to $12.8 million in 2025) in series A funding, including $6.5 million (equivalent to $11.1 million in 2025) from Elon Musk, who had received $176 million from the sale of his interest in PayPal two years earlier.[15] Musk became the chairman of the board of directors and the largest shareholder of Tesla.[16][17][13] J. B. Straubel joined Tesla in May 2004 as chief technical officer.[18]\n\nA lawsuit settlement agreed to by Eberhard and Tesla in September 2009 allows all five – Eberhard, Tarpenning, Wright, Musk, and Straubel – to call themselves co-founders.[19]\n\nRoadster (2005–2009)\nMain article: Tesla Roadster (first generation)\nElon Musk took an active role within the company, but was not deeply involved in day-to-day business operations.[20] The company\'s strategy was to start with a premium sports car aimed at early adopters and then move into more mainstream vehicles, including sedans and affordable compacts.[21]\n\nIn February 2005, Musk led Tesla\'s Series B venture capital funding round of $13 million, which added Va ...

# %%
#Directory Loader
from langchain_community.document_loaders import DirectoryLoader

loader = DirectoryLoader(
    "./docs",
    glob="**/*.txt",
    loader_cls= TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

document = loader.load()

document
# Out:
# [Document(metadata={'source': 'docs\\google.txt'}, page_content='Google LLC (/ˈɡuː.ɡəl/ ⓘ, GOO-gəl) is an American multinational technology corporation focused on information technology, online advertising, search engine technology, email, cloud computing, software, quantum computing, e-commerce, consumer electronics, and artificial intelligence (AI).[9] It has been referred to as "the most powerful company in the world" by the BBC,[10] and is one of the world\'s most valuable brands.[11][12][13] Google\'s parent company Alphabet Inc. has been described as a Big Tech company.\n\nGoogle was founded in 1998 by American computer scientists Larry Page and Sergey Brin. Together, they own about 14% of its publicly listed shares and control 56% of its stockholder voting power through super-voting stock. The company went public via an initial public offering (IPO) in 2004. In 2015, Google was reorganized as a wholly owned subsidiary of Alphabet Inc. Google is Alphabet\'s largest subsidiary and is a holding company for Alphabet\'s internet properties and interests. Sundar Pichai was appointed CEO of Google in 2015, replacing Larry Page, who became the CEO of Alphabet. In 2019, Pichai also became the CEO of Alphabet.[14]\n\nAfter the success of its original service, Google Search (often known simply as "Google"), the company has rapidly grown to offer a multitude of products and services. These products address a wide range of use cases, including email (Gmail), navigation and mapping (Waze, Maps, and Earth), cloud computing (Cloud), web navigation (Chrome), video sharing (YouTube), productivity (Workspace), operating systems (Android and ChromeOS), cloud storage (Drive), language translation (Translate), photo storage (Photos), videotelephony (Meet), smart home (Nest), smartphones (Pixel), wearable technology (Pixel Watch and Fitbit), music streaming (YouTube Music), video on demand (YouTube TV), AI (Google Assistant and Gemini), machine learning APIs (TensorFlow), AI chips (TPU), and more. Many of these products and services are dominant in their respective industries, as is Google Search. Discontinued Google products include gaming (Stadia),[15] Glass, Google+, Reader, Play Music, Nexus, Hangouts, and Inbox by Gmail.[16][17] Google\'s other ventures outside of internet services and consumer electronics include quantum computing (Willow, Google Quantum AI), self-driving cars (Waymo), and transformer models (Google DeepMind).[18]\n\nGoogle Search and YouTube are the two most-visited websites worldwide, followed by Facebook, Instagram, and ChatGPT. Google is the largest provider of search engines, mapping and navigation applications, email services, office suites, online video platforms, photo and cloud storage, mobile operating systems, web browsers, machine learning frameworks, and AI virtual assistants in the world as measured by market share.[19] Google was ranked the second most valuable brand by Forbes as of January 2022,[20] and fourth by Interbrand as of February 2022.[21] The company has received criticism involving issues such as privacy concerns, tax avoidance, censorship, search neutrality, antitrust, and abuse of its monopoly position.[22]\n\nHistory\nMain articles: History of Google and List of mergers and acquisitions by Alphabet\nSee also: Alphabet Inc.\nEarly years\nLarry Page and Sergey Brin\nLarry Page and Sergey Brin in 2003\nEric Schmidt, Sergey Brin, and Larry Page sitting together\nThen chairman and CEO Eric Schmidt (left) with co-founders Sergey Brin (center) and Larry Page (right) in 2008\nGoogle began in January 1996 as a research project by Larry Page and Sergey Brin[23][24][25] with additional contribution from Scott Hassan.[26][27] Page and Brin published their research, along with Rajeev Motwani and Terry Winograd, as the PageRank algorithm[28] and Stanford owned the patent.[29] PageRank determines a website\'s relevance by the pages that linked back to the original site.[30][31][28] Page told his ideas to  ...
#  Document(metadata={'source': 'docs\\microsoft.txt'}, page_content='Microsoft Corporation is an American multinational technology company headquartered in Redmond, Washington. The company became influential in the rise of personal computers through software like Windows and has since expanded into areas such as Internet services, cloud computing, artificial intelligence, video gaming, and more. A Big Tech company, Microsoft is the largest software company by revenue, one of the most valuable public companies, and one of the most valuable brands globally.\n\nFounded in 1975 by Bill Gates and Paul Allen to market BASIC interpreters for the Altair 8800, Microsoft rose to dominate the PC operating system market with MS-DOS in the mid-1980s, followed by Windows. The company\'s 1986 initial public offering (IPO) and subsequent rise in its share price created three billionaires and an estimated 12,000 millionaires among Microsoft employees. Since the 1990s, it has increasingly diversified its business. Steve Ballmer replaced Gates as CEO in 2000. He oversaw the then-largest of Microsoft\'s corporate acquisitions in Skype Technologies in 2011, an increased focus on hardware that led to its first in-house PC line—the Surface—in 2012, and the formation of Microsoft Mobile through Nokia. Since Satya Nadella became CEO in 2014, the company has changed focus towards cloud computing and acquired LinkedIn in 2016. Under his direction, the company has expanded its video gaming business to support the Xbox brand, establishing the Microsoft Gaming division in 2022 and acquiring Activision Blizzard in 2023.\n\nMicrosoft has been dominant in the IBM PC–compatible operating system and office software suite markets since the 1990s. Its best-known software products are the Windows line of operating systems and the Microsoft Office and Microsoft 365 suite of productivity applications, which most notably include the Word word processor, Excel spreadsheet editor, and PowerPoint presentation program. Its flagship hardware products are the Surface lineup of PCs and the Xbox brand of video game consoles, the latter including the Xbox network. The company also provides a range of consumer Internet services such as Bing web search, the MSN web portal, the Outlook.com (Hotmail) email service, and the Microsoft Store. Microsoft also has Microsoft rewards, a site where you earn points by searching on Bing. In the enterprise and development fields, Microsoft. most notably provides the Azure cloud computing platform, Microsoft SQL Server database software, and Visual Studio.\n\nMicrosoft became the third publicly traded U.S. company to be valued at over $1 trillion in April 2019. It has been criticized for monopolistic practices, and the company\'s software received criticism for problems with ease of use, robustness, and security. Microsoft has also been criticized for its role in providing services to Israel during the Gaza war.\n\nHistory\nMain article: History of Microsoft\nFor a chronological guide, see Timeline of Microsoft.\n1972–1985: Founding\n\nAn Altair 8800 computer (left) with the popular Model 33 ASR Teletype as terminal, paper tape reader, and paper tape punch\n\nPaul Allen and Bill Gates on October 19, 1981, after signing a pivotal contract with IBM[2]:\u200a228\u200a\n\nBill Gates and Paul Allen\'s Original Business Cards located in the Microsoft Visitor Center\nChildhood friends Bill Gates and Paul Allen sought to make a business using their skills in computer programming.[3] In 1972, they founded Traf-O-Data, which sold a rudimentary computer to track and analyze automobile traffic data.[4]\n\nThe January 1975 issue of Popular Electronics featured Micro Instrumentation and Telemetry Systems\'s (MITS) Altair 8800 microcomputer,[5] which inspired Allen to suggest that they could program a BASIC interpreter for the device. Gates called MITS and claimed that he had a working interpreter, and MITS requested a demonstration. Allen worked on a simula ...
#  Document(metadata={'source': 'docs\\nvidia.txt'}, page_content='Nvidia Corporation[a] (/ɛnˈvɪdiə/ en-VID-ee-ə) is an American multinational technology company headquartered in Santa Clara, California. The company develops graphics processing units (GPUs), systems on chips (SoCs), and application programming interfaces (APIs) for data science, high-performance computing, artificial intelligence (AI), and mobile and automotive applications.[5][6] Founded in 1993 by Jensen Huang, Chris Malachowsky, and Curtis Priem, Nvidia has been widely described as a Big Tech company.\n\nOriginally focused on GPUs for video games, Nvidia broadened their use into other markets, including artificial intelligence (AI), professional visualization, and supercomputing. The company\'s product lines include GeForce GPUs for gaming and creative workloads, and professional GPUs for edge computing, scientific research, and industrial applications. As of the first quarter of 2025, Nvidia held a 92% share of the discrete desktop and laptop GPU market.[7][8]\n\nIn the early-to-mid 2000s, the company invested over a billion dollars to develop CUDA, a software platform and API (Application Programming Interfaces) that enabled GPUs to run massively parallel programs for a broad range of compute-intensive applications.[9][10][11] As a result, as of 2025, Nvidia controlled more than 80% of the market for GPUs used in training and deploying AI models,[9] and provided chips for over 75% of the world\'s TOP500 supercomputers.[1] The company has also expanded into gaming hardware and services, with products such as the Shield Portable, Shield Tablet, and Shield TV, and operates the GeForce Now cloud gaming service.[12] Furthermore, it has developed the Tegra line of mobile processors for smartphones, tablets, and automotive infotainment systems.[13][14][15]\n\nIn 2023, Nvidia became the seventh U.S. company to reach a US$1 trillion valuation.[16] In 2025, amid increased demand for AI data center hardware in the midst of the AI boom, Nvidia became the first company in the world to surpass US$4 trillion[17][18] and US$5 trillion in market capitalization.[19] Because of its market capitalization and role in major technology indexes, Nvidia has been selected as one of Bloomberg\'s "Magnificent Seven", the seven biggest companies on the stock market in these regards.[20]\n\nHistory\nFounding\n\nThe Denny\'s roadside diner in San Jose, California, where Nvidia\'s three co-founders agreed to start the company in late 1992\n\nNvidia\'s former headquarters which was home to the company through most of its pre-AI period (still in use)\n\nAerial view of Endeavor, the first of the two new Nvidia headquarters buildings, in Santa Clara, California, in 2017\n\nEntrance of Endeavor headquarters building in 2018\nNvidia was founded on April 5, 1993,[21][22][23] by Jensen Huang, a Taiwanese-American electrical engineer who was previously the director of CoreWare at LSI Logic and a microprocessor designer at AMD; Chris Malachowsky, an engineer who worked at Sun Microsystems; and Curtis Priem, who was previously a senior staff engineer and graphics chip designer at IBM and Sun Microsystems.[24][25] In late 1992, the three men agreed to start the company in a meeting at a Denny\'s roadside diner on Berryessa Road in East San Jose.[26][27][28][29]\n\nAt the time, Malachowsky and Priem were frustrated with Sun\'s management and were looking to leave, but Huang was on "firmer ground",[30] in that he was already running his own division at LSI.[27] The three co-founders discussed a vision of the future which was so compelling that Huang decided to leave LSI[30] and become the chief executive officer of their new startup.[27]\n\nThe three co-founders envisioned graphics-based processing as the best trajectory for tackling challenges that had eluded general-purpose computing methods.[30] As Huang later explained: "We also observed that video games were simultaneously one of the most computat ...
#  Document(metadata={'source': 'docs\\spacex.txt'}, page_content='Space Exploration Technologies Corp., doing business as SpaceX, is an American spaceflight, telecommunications, and artificial intelligence company headquartered at the Starbase development site in Starbase, Texas.[7] The company operates three divisions: "Space", which conducts more orbital launches annually than any other launch provider, including national programs;[8][9] "Connectivity", which operates Starlink, a communications satellite company; and "Artificial intelligence", which operates Grok, X, and data centers.[2]\n\nThe company is credited with advances in rocket propulsion, reusable launch vehicles, human spaceflight, satellite constellation technology. The company\'s largest customers include NASA, the United States Space Force, and the National Reconnaissance Office. Elon Musk owns 42% of the outstanding shares of SpaceX and controls 85% of the voting power via his super-voting stock.\n\nSpaceX was founded in 2002 by Elon Musk with the goal of reducing spaceflight costs, improving the reliability of access to outer space for ordinary humans, and colonizing Mars. In 2008, after three failed attempts between 2006 and 2008 that almost pushed the company to bankruptcy, SpaceX successfully launched the Falcon 1 into orbit, becoming the first private company to develop and launch a liquid-fueled rocket to orbit. In 2010, the company launched the Falcon 9 launch vehicle and the Dragon 1 spacecraft to fulfill NASA\'s Commercial Orbital Transportation Services (COTS) contracts for cargo deliveries to the International Space Station (ISS). In 2012, SpaceX began flying Commercial Resupply Services missions to the ISS, becoming the first private company to successfully dock with the station, and started developing technologies to make the Falcon 9 first stage reusable. In 2015, Falcon 9 flight 20 was the first successful landing of an orbital-class rocket\'s first stage and the company\'s SES-10 completed the first reflight of an orbital-class booster in 2017. After a decade of development, the Falcon Heavy, which consists of three Falcon 9-derived boosters, made its maiden flight in 2018. As of May 2026, Falcon 9 launches averaged approximately three missions per week, and Falcon boosters had completed nearly 650 landings and reflights.\n\nIn 2019, the first operational satellite of the Starlink internet satellite constellation came online, diversifying the revenue of the company. Starlink has generated the bulk of SpaceX\'s income and led to its Starshield military counterpart. In 2020, SpaceX began to operate its Dragon 2 capsules for NASA and private entity crewed missions. Around this time, SpaceX began building test prototypes for SpaceX Starship, the largest launch vehicle in history. SpaceX plans to adapt it as a human lander for lunar missions under NASA\'s Artemis program.[10] In 2026, SpaceX acquired Musk\'s artificial intelligence company xAI, and announced a joint venture with Tesla, Inc. to build Terafab, a large plant for semiconductor device fabrication. The initial public offering of SpaceX on June 12, 2026, which raised $86 billion,[11] was the largest IPO in history and briefly made Musk the first US-dollar trillionaire.[12][13]\n\nHistory\nMain article: History of SpaceX\nSee also: List of Falcon 9 and Falcon Heavy launches\n2001–2002: Founding\nIn early 2001, Elon Musk met Robert Zubrin and donated $100,000 to his Mars Society and briefly joined its board of directors.[14]:\u200a30–31\u200a In August 2001, he gave a plenary talk at their fourth convention where he announced Mars Oasis, a project to land a greenhouse and grow plants on Mars.[15][16]\n\nMusk initially attempted to acquire a Dnepr launch vehicle for the project through Russian contacts provided by Jim Cantrell; however, he was unsuccessful.[17]\n\nMusk returned with his team to Moscow, this time bringing Michael D. Griffin, who later became the 11th Administrator of NASA, but ...
#  Document(metadata={'source': 'docs\\tesla.txt'}, page_content='Tesla, Inc. (/ˈtɛzlə/ TEZ-lə or /ˈtɛslə/ ⓘ TESS-lə[a]) is an American multinational automotive and clean energy company. Headquartered in Austin, Texas, it designs, manufactures, and sells battery electric vehicles (BEVs), stationary battery energy storage devices from home to grid-scale, solar panels and solar shingles, and related products and services.\n\nThe company was incorporated in July 2003 by Martin Eberhard and Marc Tarpenning as Tesla Motors. Its name is a tribute to the inventor and electrical engineer Nikola Tesla. In February 2004, Elon Musk led Tesla\'s first funding round and became the company\'s chairman, subsequently claiming to be a co-founder; in 2008, he was named chief executive officer. The company began production of its first car model, the Roadster sports car, in 2008; the Model S sedan in 2012; the Model X SUV in 2015; the Model 3 sedan in 2017; the Model Y crossover in 2020; the Tesla Semi truck in 2022; and the Cybertruck pickup truck in 2023.\n\nTesla is one of the world\'s most valuable companies in terms of market capitalization. Starting in July 2020, it has been the world\'s most valuable automaker. From October 2021 to March 2022, Tesla was a US$1 trillion company, the sixth US company to reach that valuation. In 2023, the company was ranked 69th in the Forbes Global 2000.[5] In 2024, the company led the battery electric vehicle market, with 17.6% share.\n\nTesla exceeded $1 trillion in market capitalization again between November 2024[6] and February 2025,[7] and from May 2025 to July 2026.[8] In November 2025, Tesla approved a pay package worth $1 trillion for Musk, which he is to receive over 10 years if he meets specific goals.[9] By the end of 2025, the company lost its status as world\'s leading manufacturer of electric vehicles.[10]\n\nTesla has been the subject of lawsuits, boycotts, government scrutiny, and journalistic criticism, stemming from allegations of multiple cases of whistleblower retaliation, worker rights violations such as sexual harassment and anti-union activities, safety defects leading to dozens of recalls, the lack of a public relations department, and controversial statements from Musk, including overpromising on the company\'s driving assist technology and product release timelines.\n\nHistory\nMain article: History of Tesla, Inc.\nFounding (2003–2004)\nThe company was incorporated as Tesla Motors, Inc., on July 1, 2003, by Martin Eberhard and Marc Tarpenning.[11][12] They served as chief executive officer and chief financial officer, respectively.[13] Eberhard said that he wanted to build "a car manufacturer that is also a technology company", with its core technologies as "the battery, the computer software, and the proprietary motor".[14]\n\nIan Wright joined Eberhard and Tarpenning a few months later.[11] In February 2004, the company raised US$7.5 million (equivalent to $12.8 million in 2025) in series A funding, including $6.5 million (equivalent to $11.1 million in 2025) from Elon Musk, who had received $176 million from the sale of his interest in PayPal two years earlier.[15] Musk became the chairman of the board of directors and the largest shareholder of Tesla.[16][17][13] J. B. Straubel joined Tesla in May 2004 as chief technical officer.[18]\n\nA lawsuit settlement agreed to by Eberhard and Tesla in September 2009 allows all five – Eberhard, Tarpenning, Wright, Musk, and Straubel – to call themselves co-founders.[19]\n\nRoadster (2005–2009)\nMain article: Tesla Roadster (first generation)\nElon Musk took an active role within the company, but was not deeply involved in day-to-day business operations.[20] The company\'s strategy was to start with a premium sports car aimed at early adopters and then move into more mainstream vehicles, including sedans and affordable compacts.[21]\n\nIn February 2005, Musk led Tesla\'s Series B venture capital funding round of $13 million, which added Val ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = DirectoryLoader(
    "./docs/pdf",
    glob="**/*.pdf",
    loader_cls= PyMuPDFLoader,
    show_progress=False
)

pdf_document = loader.load()

pdf_document
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 0}, page_content='INVOLVE: An AI-Powered On-Demand Local Services Platform with Intelligent \nIssue Diagnosis and Emergency-Based Worker Assignment \n \nABSTRACT \nIn today’s fast-paced world, people frequently encounter unexpected situations such as \nvehicle breakdowns, electrical faults, plumbing failures, urgent grooming requirements, and \nhome maintenance emergencies that require immediate professional assistance. However, \nlocating a reliable and available service provider within a short time remains a significant \nchallenge due to delayed responses, limited service availability, lack of pricing transparency, \nand poor communication. Existing service platforms primarily focus on scheduled bookings \nand often fail to address emergency situations effectively. They also lack intelligent problem \nassessment, real-time tracking, and efficient worker allocation, resulting in longer waiting \ntimes and reduced customer satisfaction. \nINVOLVE is an AI-powered on-demand local services platform designed to bridge this gap by \nproviding fast, reliable, and intelligent service delivery. The platform integrates AI-based \nissue diagnosis using user descriptions and images to identify problems accurately and \nestimate their severity. Based on the emergency level, worker expertise, availability, \nproximity, ratings, and historical performance, the system intelligently assigns the most \nsuitable verified professional instead of simply selecting the nearest one. Additional features \nsuch as real-time GPS tracking, ETA prediction, dynamic pricing, and blockchain-secured \npayments further enhance transparency, security, and user trust. By ensuring a guaranteed \n10-minute response time for emergency requests, INVOLVE aims to improve service \nefficiency, minimize response delays, and deliver a seamless, technology-driven experience \nfor both customers and service professionals. \n \nKeywords:  \n• Artificial Intelligence (AI) \n• On-Demand Local Services  \n• Emergency Worker Assignment \n• Real-Time GPS Tracking \n• Blockchain-Based Payments'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 1}, page_content='INTRODUCTION \nThe rapid advancement of digital technology has transformed the way people access \neveryday services, making them faster, more convenient, and easily accessible. Despite this \nprogress, obtaining immediate assistance during emergency situations such as vehicle \nbreakdowns, electrical failures, plumbing leaks, appliance malfunctions, urgent home \nmaintenance, and personal care emergencies remains a significant challenge. In such \nsituations, users require quick access to reliable professionals, but existing service platforms \nare primarily designed for scheduled appointments rather than urgent requests. As a result, \nusers often experience delayed responses, uncertainty regarding service quality, lack of real-\ntime communication, and limited visibility into the progress of their service requests. \nThe emergence of Artificial Intelligence (AI), cloud computing, real-time communication \ntechnologies, and GPS-based location services provides an opportunity to improve the \nefficiency of emergency service delivery. These technologies enable intelligent decision-\nmaking by analysing user requests, identifying service requirements, estimating the severity \nof issues, and selecting the most appropriate service professional. Instead of assigning \nworkers solely based on proximity or availability, AI-powered systems can evaluate multiple \nfactors such as worker expertise, historical performance, availability, workload, customer \nratings, and estimated arrival time. This intelligent approach improves service accuracy, \nminimizes waiting time, and enhances customer satisfaction. \nAlthough several online platforms connect users with local service providers, they still suffer \nfrom important limitations. Most require advance bookings or depend on professionals to \nmanually accept service requests, making them unsuitable for emergency situations. Many \nplatforms lack intelligent problem diagnosis, transparent pricing, verified worker \ninformation, and real-time tracking, leading to inefficient worker allocation and inconsistent \nservice quality. Users often find it difficult to explain technical issues accurately, while service \nprofessionals receive insufficient information before reaching the location. Consequently, \nprofessionals may arrive without the necessary expertise or equipment, increasing service \ndelays and operational costs. Factors such as traffic congestion, uneven distribution of \nprofessionals, and unpredictable demand further reduce the effectiveness of traditional \nservice allocation methods. \nTo overcome these challenges, this project proposes INVOLVE – An AI-Powered On-Demand \nLocal Services Platform, an intelligent solution designed to provide fast, reliable, and \ntechnology-driven local services. The platform uses AI-based issue diagnosis to analyse user \ndescriptions and uploaded images, enabling accurate identification of service requirements \nand emergency severity. Based on this analysis, the system intelligently ranks and assigns \nverified professionals by considering expertise, availability, experience, proximity, workload, \ncustomer ratings, and emergency priority. Rather than simply selecting the nearest worker, \nthe platform ensures that the most suitable professional is assigned to each request, \nimproving both response quality and efficiency. \nThe proposed platform also incorporates advanced features such as real-time GPS tracking, \nintelligent Estimated Time of Arrival (ETA) pre ...
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 2}, page_content='pricing, secure blockchain-based payment processing, and continuous service status \nupdates. These features improve transparency, strengthen user trust, and provide a \nseamless experience for both customers and service professionals. By integrating Artificial \nIntelligence with modern communication and location technologies, INVOLVE aims to reduce \nresponse time, optimize worker allocation, improve service reliability, and enhance overall \ncustomer satisfaction. The platform represents a significant step toward building a smarter, \nfaster, and more efficient ecosystem for on-demand local emergency services. \n2. LITERATURE REVIEW \nThe rapid advancement of digital technology has significantly transformed the local service \nindustry by enabling users to book professionals through online platforms. Applications \nproviding home maintenance, repair, beauty, vehicle assistance, and appliance servicing \nhave replaced traditional methods of searching for local workers through personal contacts \nor offline agencies. Platforms such as Urban Company, TaskRabbit, and Thumbtack have \ndemonstrated that digital marketplaces can improve accessibility, transparency, and \nconvenience by connecting customers with verified service providers. These platforms offer \nfeatures such as online booking, customer reviews, digital payments, and service tracking. \nAlthough they have simplified the process of obtaining local services, they primarily focus on \nscheduled appointments and are not specifically designed to handle emergency situations \nrequiring immediate assistance. \nSeveral researchers have emphasized the importance of Artificial Intelligence (AI) in \nenhancing service management systems. AI techniques such as machine learning, \nrecommendation systems, and predictive analytics enable intelligent analysis of user \nrequests and support automated decision-making. Existing studies show that AI can evaluate \nmultiple parameters, including worker expertise, availability, customer ratings, historical \nperformance, and workload, to recommend suitable professionals. Compared with \ntraditional first-come-first-served or nearest-worker allocation methods, AI-based worker \nselection improves assignment accuracy and reduces service delays. However, many \ncommercial platforms continue to rely mainly on location-based matching, limiting their \nability to provide the most qualified professional for complex or urgent service requests. \nRecent developments in Natural Language Processing (NLP) have further expanded the \ncapabilities of intelligent service platforms. NLP techniques allow systems to analyse user \ndescriptions, identify the nature of reported problems, and classify service requests \nautomatically. Instead of relying entirely on manual categorization, AI-based text analysis \nimproves the accuracy of service identification while reducing communication gaps between \ncustomers and professionals. Researchers have demonstrated that NLP-based issue \nclassification significantly improves response efficiency, particularly when users lack \ntechnical knowledge to explain problems accurately. \nComputer vision has also emerged as an important technology for service diagnosis. Deep \nlearning models trained on images can identify visible faults such as plumbing leaks, \nelectrical damage, vehicle defects, cracked appliances, or structural problems. Image-based \ndiagnosis provides additional information that helps professionals estimate service'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 3}, page_content="complexity before reaching the customer's location. Research suggests that combining \nimage analysis with textual descriptions improves diagnostic accuracy and reduces \nunnecessary repeat visits. Despite these advantages, most existing local service platforms \nstill depend mainly on manual descriptions without integrating intelligent image analysis into \ntheir booking systems. \nLocation-aware technologies have become essential components of modern on-demand \nservice applications. GPS-based tracking enables platforms to identify nearby professionals, \nmonitor worker movement, estimate arrival time, and provide customers with real-time \nservice updates. Several studies have shown that integrating traffic information, road \nconditions, and predictive Estimated Time of Arrival (ETA) algorithms improves route \noptimization and minimizes customer waiting time. Nevertheless, many existing systems \nassign workers solely based on distance while ignoring expertise, workload distribution, \nemergency severity, and historical service quality, resulting in inefficient resource utilization. \nDynamic pricing has also received considerable attention in recent research. Pricing models \nbased on demand, service complexity, urgency, travel distance, and resource availability help \nmaintain fairness for both customers and service providers. Intelligent pricing algorithms \nensure transparent cost estimation before service confirmation, improving customer trust \nand reducing pricing disputes. However, many current service platforms provide fixed or \nmanually estimated prices that fail to reflect real-time operating conditions and emergency \npriorities. \nAnother important area of research involves secure digital payment systems. Blockchain \ntechnology has emerged as a reliable solution for protecting financial transactions through \ndecentralized and tamper-resistant record management. Researchers have highlighted the \nadvantages of blockchain in ensuring payment transparency, preventing fraud, maintaining \ntransaction integrity, and increasing trust among stakeholders. Although blockchain has \nbeen widely studied in banking, healthcare, and supply chain management, its \nimplementation in local service platforms remains relatively limited, particularly for \nemergency service applications. \nThe proposed project, INVOLVE – An AI-Powered On-Demand Local Services Platform, builds \nupon these research findings by integrating multiple advanced technologies into one unified \nsolution. The platform combines AI-based problem diagnosis, image-assisted issue \nidentification, intelligent worker ranking based on expertise, availability, workload, and \nemergency priority, real-time GPS tracking, ETA prediction, dynamic pricing, and blockchain-\nenabled secure payments. Unlike conventional platforms that primarily emphasize \nscheduled bookings, INVOLVE focuses on rapid emergency response and intelligent decision-\nmaking. By selecting the most suitable verified professional rather than merely the nearest \navailable worker, the platform aims to reduce response time, improve service reliability, \noptimize resource utilization, and enhance overall customer satisfaction. This integrated \napproach addresses the shortcomings identified in previous studies and contributes toward \nthe development of a smarter, faster, and more dependable local emergency service \nplatform."),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 4}, page_content="3. Problem Statement & Objectives \nProblem Statement \nIn today's fast-paced lifestyle, people frequently encounter emergency situations such as \nvehicle breakdowns, electrical faults, plumbing leaks, appliance failures, and urgent home \nmaintenance that require immediate professional assistance. However, existing local service \nplatforms primarily focus on scheduled bookings and often fail to provide rapid responses \nduring emergencies. Users experience long waiting times, difficulty finding qualified \nprofessionals, lack of transparent pricing, limited real-time tracking, and inefficient \ncommunication. Moreover, current systems generally assign workers based only on \nproximity or availability without considering factors such as expertise, workload, emergency \nseverity, and historical performance. The absence of AI-based issue diagnosis further \nincreases the chances of incorrect service allocation, repeated visits, and delayed problem \nresolution. These limitations reduce service efficiency, customer satisfaction, and overall \nreliability. Therefore, there is a need for an intelligent, technology-driven platform that can \naccurately identify user problems, prioritize emergency requests, and assign the most \nsuitable verified professional while ensuring transparency, security, and real-time \ncommunication throughout the service process. \nObjectives of the Study \nThe primary objective of this project is to design and develop INVOLVE – An AI-Powered On-\nDemand Local Services Platform that delivers fast, reliable, and intelligent emergency \nassistance. The specific objectives are: \n• \nTo provide instant service booking with minimal response time. \n• \nTo implement AI-based issue diagnosis using user descriptions and images. \n• \nTo intelligently assign verified professionals based on expertise, availability, \nemergency priority, and location. \n• \nTo enable real-time GPS tracking and ETA prediction for service monitoring. \n• \nTo ensure transparent dynamic pricing and secure blockchain-based digital \npayments. \n• \nTo offer a user-friendly, reliable, and 24×7 emergency service platform for customers \nand professionals. \n4. Proposed Methodology \nThe proposed methodology presents the design and implementation approach of INVOLVE – \nAn AI-Powered On-Demand Local Services Platform, developed to provide fast, reliable, and \nintelligent emergency assistance for local service requests. The methodology integrates \nArtificial Intelligence (AI), cloud computing, real-time communication, geolocation services, \nand blockchain technology to create a unified platform that improves response time, service \nquality, and operational efficiency. Unlike conventional service applications that simply"),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 5}, page_content="connect users with nearby professionals, the proposed system analyses the nature of the \nreported problem, determines its urgency, and intelligently assigns the most suitable verified \nworker based on multiple evaluation parameters. \nThe service process begins when a user submits a request through the web or mobile \napplication. Users can describe the issue using text, upload one or more images, or provide \nvoice input for better explanation. The platform collects the user's location through GPS and \nsecurely transmits the request to the server. This information serves as the input for the AI \nengine, which performs preliminary issue analysis before assigning a professional. \nThe Artificial Intelligence module plays a central role in the proposed methodology. It \nanalyses the user's description and uploaded images to identify the probable problem, \nestimate its severity, and classify the request into the appropriate service category, such as \nplumbing, electrical repair, appliance maintenance, vehicle assistance, or home services. The \nAI module also determines whether the request should be treated as an emergency or a \nnormal service request. This intelligent diagnosis reduces communication errors, helps users \ndescribe technical problems more accurately, and enables professionals to prepare the \nnecessary tools and equipment before arriving at the service location. \nOnce the service category and priority level are determined, the worker assignment module \nsearches for all verified professionals available within the service area. Instead of assigning \nonly the nearest worker, the system evaluates multiple parameters, including professional \nexpertise, certification, service experience, customer ratings, historical performance, current \nworkload, availability, travel distance, estimated arrival time, and emergency priority. Each \nprofessional is assigned a suitability score based on these factors. The worker with the \nhighest score is selected to ensure that users receive assistance from the most qualified \nprofessional rather than simply the closest one. This intelligent allocation improves service \nquality, reduces repeated visits, and optimizes workforce utilization. \nAfter successful assignment, both the customer and the service professional receive instant \nnotifications through the real-time communication system. Technologies such as Socket.IO \nand Redis enable immediate synchronization of assignment status, service progress, and \nlocation updates between all participants. Customers can monitor the professional's live \nlocation using GPS tracking, while the system continuously calculates the Estimated Time of \nArrival (ETA) by considering current traffic conditions and route optimization. Real-time \nupdates improve transparency, reduce uncertainty, and allow users to prepare before the \nprofessional arrives. \nThe proposed methodology also incorporates a dynamic pricing mechanism that estimates \nservice charges based on service category, complexity of the issue, travel distance, \nemergency priority, and expected repair effort. Users receive a transparent cost estimate \nbefore confirming the booking, minimizing pricing disputes and improving trust. Following \nsuccessful service completion, payments are processed through a blockchain-enabled \npayment system that securely records transaction details. Blockchain technology ensures \ntransparency, prevents transaction manipulation, and provides secure digital pay ...
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 6}, page_content='Administrators play an important role in maintaining the platform. They verify worker \nregistrations, approve certifications, monitor service quality, resolve customer complaints, \nmanage service categories, and analyse system performance using service analytics. \nHistorical service records are stored securely within the database and can be used by the AI \nmodule to continuously improve diagnosis accuracy, worker recommendation, and \nemergency response strategies through machine learning techniques. \nThe proposed methodology follows a modular architecture consisting of the presentation \nlayer, application layer, AI layer, real-time communication layer, and security layer. This \nlayered architecture improves scalability, maintainability, and future expansion while \nensuring secure communication through REST APIs and encrypted data transfer. The system \nis designed to support increasing numbers of users and professionals without affecting \nperformance. \nOverall, the proposed methodology provides an intelligent framework for modern \nemergency local services by combining AI-driven issue diagnosis, smart worker assignment, \nreal-time GPS tracking, ETA prediction, dynamic pricing, secure blockchain-based payments, \nand continuous monitoring into a single integrated platform. By reducing response time, \nimproving decision-making, enhancing transparency, and optimizing resource allocation, \nINVOLVE delivers a reliable, efficient, and user-centric solution that addresses the \nshortcomings of traditional local service platforms while meeting the growing demand for \nrapid emergency assistance. \n5. Result Analysis \nThe proposed INVOLVE – AI-Powered On-Demand Local Services Platform was successfully \ndesigned, developed, and evaluated to determine its effectiveness in providing intelligent \nand efficient emergency local service management. The platform integrates Artificial \nIntelligence (AI), real-time communication, GPS-based tracking, intelligent worker \nrecommendation, ETA prediction, dynamic pricing, and blockchain-secured digital payments \ninto a unified system. The primary objective of the evaluation was to verify whether the \nproposed platform could overcome the limitations of traditional service booking applications \nby reducing response time, improving worker assignment accuracy, enhancing service \nreliability, and providing greater transparency throughout the service lifecycle. \nFunctional testing was performed on all major modules of the platform under different \nemergency service scenarios, including electrical faults, plumbing issues, vehicle \nbreakdowns, appliance repair, and home maintenance requests. The testing confirmed that \nthe system successfully executes the complete service workflow, beginning with user \nregistration and request submission, followed by AI-based issue diagnosis, intelligent worker \nassignment, real-time communication, service tracking, secure payment processing, and \ncustomer feedback collection. Users were able to submit service requests through text \ndescriptions and image uploads, enabling the AI engine to analyse the reported issue and \ndetermine the appropriate service category and emergency priority.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 7}, page_content="The AI-based diagnosis module demonstrated effective performance by reducing \ncommunication gaps between customers and professionals. By analysing textual descriptions \nand uploaded images, the system identified the probable issue before assigning a worker. \nThis enabled professionals to understand the service requirements in advance and prepare \nthe necessary tools and equipment before reaching the customer's location. Consequently, \nunnecessary repeat visits were minimized, improving first-time service completion and \noverall service efficiency. \nThe intelligent worker recommendation module produced better assignment results than \ntraditional location-based matching systems. Instead of assigning the nearest available \nprofessional, the platform evaluated multiple decision parameters, including worker \nexpertise, certification, customer ratings, historical performance, current workload, \navailability, travel distance, and emergency priority. Based on these factors, the AI generated \na suitability score for each professional and selected the most appropriate worker. This \napproach improved assignment accuracy, balanced workload distribution, and increased the \nlikelihood of successful service completion within the shortest possible time. \nThe real-time communication and GPS tracking modules also demonstrated reliable \nperformance during evaluation. Customers received continuous notifications regarding \nrequest status, worker assignment, estimated arrival time, and service completion. Live GPS \ntracking enabled users to monitor the movement of the assigned professional throughout \nthe service journey. The ETA prediction module combined GPS data with traffic conditions to \nprovide accurate arrival estimates, reducing customer uncertainty and improving \ntransparency during emergency situations. \nThe dynamic pricing module successfully calculated service charges based on multiple \nparameters, including service category, issue complexity, travel distance, emergency priority, \nand estimated repair effort. Transparent pricing was displayed before booking confirmation, \nallowing customers to understand the expected cost in advance and reducing billing \ndisputes. After successful service completion, the blockchain-enabled payment module \nsecurely processed digital transactions while maintaining tamper-resistant payment records. \nThis enhanced financial security and increased trust between customers and service \nprofessionals. \nOverall, the proposed platform demonstrated significant improvements compared with \nconventional local service applications. The integration of Artificial Intelligence enabled \nintelligent issue diagnosis and worker recommendation, while real-time communication \nimproved coordination among users, professionals, and administrators. GPS tracking and ETA \nprediction enhanced transparency, and blockchain-based payment verification ensured \nsecure financial transactions. The platform achieved faster emergency response, improved \nworker utilization, higher assignment accuracy, better service reliability, and increased \ncustomer satisfaction. These results validate that the proposed methodology provides an \nefficient, scalable, and user-centric solution for modern on-demand local emergency \nservices."),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 8}, page_content='6. DISCUSSION \nThe implementation and evaluation of INVOLVE – An AI-Powered On-Demand Local Services \nPlatform demonstrate the effectiveness of integrating Artificial Intelligence with modern \ncommunication and location-based technologies to improve emergency local service \ndelivery. The results indicate that AI-based issue diagnosis and intelligent worker \nrecommendation significantly enhance the efficiency of service allocation compared with \nconventional platforms that primarily rely on manual booking or proximity-based \nassignment. By considering factors such as worker expertise, availability, customer ratings, \nworkload, emergency priority, and travel distance, the system is able to assign the most \nsuitable professional for each request. \nThe integration of real-time GPS tracking and ETA prediction improves transparency by \nallowing users to monitor service progress and receive accurate arrival estimates. Dynamic \npricing further enhances customer trust by providing clear and fair cost estimation before \nservice confirmation, while blockchain-based payment verification ensures secure and \ntamper-resistant digital transactions. These features collectively contribute to improved \ncustomer satisfaction and operational efficiency. \nAlthough the proposed platform demonstrates promising performance, certain challenges \nremain. The accuracy of AI-based issue diagnosis depends on the quality of user-provided \ndescriptions and uploaded images. In addition, reliable internet connectivity and GPS \navailability are essential for real-time communication and location tracking. Future \nimprovements may include multilingual AI support, voice-based diagnosis, predictive \ndemand forecasting, IoT-based fault detection, and advanced machine learning models for \nmore accurate worker recommendation. Overall, the proposed system provides a scalable, \nintelligent, and reliable solution that addresses the shortcomings of existing local service \nplatforms while meeting the growing demand for rapid emergency assistance. \n7. CONCLUSION AND FUTURE WORK \nThe proposed INVOLVE – An AI-Powered On-Demand Local Services Platform successfully \ndemonstrates the potential of integrating Artificial Intelligence, real-time communication, \ngeolocation technologies, and secure digital payments to improve emergency local service \nmanagement. The platform addresses the major limitations of conventional service booking \nsystems by providing AI-based issue diagnosis, intelligent worker recommendation, \nemergency-priority handling, real-time GPS tracking, ETA prediction, dynamic pricing, and \nblockchain-enabled payment verification. Instead of assigning the nearest available worker, \nthe system evaluates multiple factors, including expertise, availability, workload, customer \nratings, and emergency severity, to assign the most suitable verified professional. This \nintelligent approach reduces response time, improves worker utilization, enhances service \nreliability, and increases customer satisfaction. The modular architecture also ensures \nscalability, flexibility, and easy integration of future technologies, making the platform \nsuitable for deployment across different cities and service categories.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-07-21T13:21:21+05:30', 'source': 'docs\\pdf\\29_Paper.pdf', 'file_path': 'docs\\pdf\\29_Paper.pdf', 'total_pages': 10, 'format': 'PDF 1.7', 'title': '', 'author': 'Faheem Jawaid', 'subject': '', 'keywords': '', 'moddate': '2026-07-21T13:21:21+05:30', 'trapped': '', 'modDate': "D:20260721132121+05'30'", 'creationDate': "D:20260721132121+05'30'", 'page': 9}, page_content='Future work will focus on enhancing the intelligence and capabilities of the platform through \nadvanced machine learning algorithms that continuously learn from historical service data to \nimprove worker recommendation and demand forecasting. Predictive analytics can be \nincorporated to identify high-demand regions and optimize workforce planning. Additional \nenhancements include multilingual voice-based AI assistants, IoT integration for automatic \nfault detection and service request generation, AI-powered fraud detection for identifying \nsuspicious activities, and dedicated Android and iOS applications. Future versions may also \nsupport offline emergency assistance, wearable device integration, and smart navigation \nusing live traffic analysis. These improvements will enable INVOLVE to evolve into a \ncomprehensive, intelligent, scalable, and user-centric emergency service ecosystem capable \nof delivering faster, safer, and more efficient local services. \n8. REFERENCES \n[1] S. Russell and P. Norvig, Artificial Intelligence: A Modern Approach, 4th ed. Pearson, 2021. \n[2] I. Goodfellow, Y. Bengio, and A. Courville, Deep Learning. MIT Press, 2016. \n[3] M. T. Hagan, H. B. Demuth, and M. H. Beale, Neural Network Design. PWS Publishing, \n2014. \n[4] M. E. Porter and J. E. Heppelmann, "How Smart, Connected Products Are Transforming \nCompetition," Harvard Business Review, vol. 92, no. 11, pp. 64–88, 2014. \n[5] M. Swan, Blockchain: Blueprint for a New Economy. O\'Reilly Media, 2015. \n[6] M. Crosby, P. Pattanayak, S. Verma, and V. Kalyanaraman, "Blockchain Technology: \nBeyond Bitcoin," Applied Innovation Review, no. 2, pp. 6–19, 2016. \n[7] R. Buyya, C. S. Yeo, and S. Venugopal, "Market-Oriented Cloud Computing: Vision, Hype, \nand Reality," Future Generation Computer Systems, vol. 25, no. 6, pp. 599–616, 2009. \n[8] T. H. Cormen, C. E. Leiserson, R. L. Rivest, and C. Stein, Introduction to Algorithms, 4th ed. \nMIT Press, 2022. \n[9] M. Fowler, Patterns of Enterprise Application Architecture. Addison-Wesley, 2002. \n[10] PostgreSQL Global Development Group, "PostgreSQL Documentation," Available: \nhttps://www.postgresql.org/docs/ \n[11] Socket.IO Team, "Socket.IO Documentation," Available: https://socket.io/docs/ \n[12] Next.js Team, "Next.js Documentation," Available: https://nextjs.org/docs \n[13] Express.js Team, "Express.js Documentation," Available: https://expressjs.com/ \n[14] Redis Labs, "Redis Documentation," Available: https://redis.io/docs/ \n[15] Apache Software Foundation, "Apache Kafka Documentation," Available: \nhttps://kafka.apache.org/documentation/'),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-04-21T05:36:29+00:00', 'source': 'docs\\pdf\\FaheemJawaidResume.pdf', 'file_path': 'docs\\pdf\\FaheemJawaidResume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-21T05:36:29+00:00', 'trapped': '', 'modDate': 'D:20260421053629Z', 'creationDate': 'D:20260421053629Z', 'page': 0}, page_content='Faheem Jawaid\n§ iamfj03 | # faheemjawaid12@gmail.com | \x83 +91-9334395200\nWork Experience\nEuphoria Genx\nJuly 2025 - January 2026\n*Completed 6-month onsite MERN stack training program, gaining hands-on experience in MongoDB,\nExpress, React, and Node.js, and developing practical full-stack projects.\n*Worked on real-world projects to implement CRUD operations, REST APIs, and responsive front-\nend interfaces, applying best practices in full-stack web development.\nProjects\nMeal Recipe Finder – MERN, Tailwind, Razorpay, Edamam API\nLive | Code\n* Designed a MERN-based meal recipe platform with JWT-based authentication stored in HTTP\ncookies and a responsive UI, serving 20+ recipes via the Edamam API.\n* Implemented a usage-based subscription model with 3 free trials, integrated Razorpay for payments,\nand managed API-driven meal data and access control.\nMeetConf – MERN, Tailwind, Socket.IO\nLive | Code\n* Developed a responsive video conferencing platform supporting 1:1 and group calls (up to 6 users)\nwith secure authentication, email verification, and user profiles.\n* Integrated Socket.IO for real-time signaling, ICE servers for peer-to-peer video streaming, and a\nscheduling module to manage upcoming meetings.\nChatConnect - Next.js, PostgreSQL, Socket.IO\nLive | Code\n* Built a real-time chat platform with user authentication, search, chat requests, and contact\nmanagement.\n* Implemented instant messaging, online status, and secure JWT-based sessions, delivering a respon-\nsive and production-ready user experience.\nEducation\n2023 - 2026\nBachelor’s Degree at NSHM Knowledge Campus, Durgapur\nCGPA: 7.8\n2020 - 2023\nDiploma at Alkabir Polytechnic, Jamshedpur\nCGPA: 7.7\nAchievements\n• Solved 130+ coding problems on LeetCode, improving algorithm efficiency and mastering data\nstructures like arrays, trees, and graphs.\n• Received Certificate of Recognition in Hacknovate 6.0 and participated in Code for Change 2025,\ncollaborating in teams to develop innovative software solutions under tight deadlines.\nSkills\nLanguages:\nC, C++, Java, JavaScript, HTML5\nStyling/Frameworks:\nTailwind CSS, REST APIs, ReactJS, Node.js, Express.js, NextJS\nDatabases/Tools:\nMongoDB, MySQL, Git, GitHub\nSoft Skills:\nEffective communication, team collaboration, critical thinking, rapid learning,\ndecision-making under pressure')]
